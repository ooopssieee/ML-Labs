# %%
# !curl https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillsNetwork/labs/Module%202/data/FuelConsumptionCo2.csv -o FuelConsumptionCo2.csv

# %%
import matplotlib.pyplot as plt
import pandas as pd
import pylab as pl
import numpy as np
from sklearn import linear_model
from sklearn.metrics import r2_score
# %matplotlib inline

# %%
df= pd.read_csv('FuelConsumption.csv')
#take a look at the dataset
df.head()
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# 2          AV7        Z                   6.0                  5.8
# 3          AS6        Z                  12.7                  9.1
# 4          AS6        Z                  12.1                  8.7
#
#    FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# 0                   8.5                        33           196
# ...

# %%
#summarize the data
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE    CYLINDERS  FUELCONSUMPTION_CITY  \
# count     1067.0  1067.000000  1067.000000           1067.000000
# mean      2014.0     3.346298     5.794752             13.296532
# std          0.0     1.415895     1.797447              4.101253
# min       2014.0     1.000000     3.000000              4.600000
# 25%       2014.0     2.000000     4.000000             10.250000
# 50%       2014.0     3.400000     6.000000             12.600000
# 75%       2014.0     4.300000     8.000000             15.550000
# max       2014.0     8.400000    12.000000             30.200000
#
#        FUELCONSUMPTION_HWY  FUELCONSUMPTION_COMB  FUELCONSUMPTION_COMB_MPG  \
# count          1067.000000           1067.000000               1067.000000
# mean              9.474602             11.580881                 26.441425
# std               2.794510              3.485595                  7.468702
# min               4.900000              4.700000                 11.000000
# ...

# %%
cdf=df[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
cdf.head(9)
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244
# 5         3.5          6                  10.0           230
# 6         3.5          6                  10.1           232
# 7         3.7          6                  11.1           255
# 8         3.7          6                  11.6           267

# %%
viz=cdf#[['ENGINESIZE','CYLINDERS','FUELCONSUMPTION_COMB','CO2EMISSIONS']]
viz.hist()
plt.show()

# %% [markdown]
# Plotting 'FuelConsumption' against 'Emission'

# %%
plt.scatter(cdf.FUELCONSUMPTION_COMB, cdf.CO2EMISSIONS, color='blue')
plt.xlabel('FuelConsumption')
plt.ylabel('Emission')
plt.show()

# %% [markdown]
# Plotting 'Cylinder' against 'Emission'

# %%
plt.scatter(cdf.CYLINDERS,cdf.CO2EMISSIONS, color='blue')
plt.xlabel('Cylinders')
plt.ylabel('Emission')
plt.show()

# %% [markdown]
# Plotting 'EngineSize' against 'Emission'

# %%
plt.scatter(cdf.ENGINESIZE,cdf.CO2EMISSIONS,color='blue')
plt.xlabel('EngineSize')
plt.ylabel('Emission')
plt.show()

# %% [markdown]
# Randomizing 0.8 of training data for out-of-sample accuracy.

# %%
msk = np.random.rand(len(df)) < 0.8
train=cdf[msk]
test=cdf[~msk]#0.2 of the data not in msk

# %% [markdown]
# SIMPLE LINEAR REGRESSION MODEL

# %%
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='blue')
plt.xlabel('EngineSize')
plt.ylabel('Emission')
plt.show()

# %% [markdown]
# TRAINING/MODELLING DATA USING 'ENGINESIZE' AGAINST 'CO2EMISSIONS'

# %%
from sklearn import linear_model
regr=linear_model.LinearRegression()
train_x=np.asanyarray(train[['ENGINESIZE']])
train_y=np.asanyarray(train[['CO2EMISSIONS']])
regr.fit(train_x,train_y)

print(f'Coefficent[Theta 1] :{regr.coef_}\nIntercept[Theta 0] :{regr.intercept_}')
# Out:
# Coefficent[Theta 1] :[[38.50380296]]
# Intercept[Theta 0] :[127.03488492]

# %% [markdown]
# Plotting fitted line

# %%
plt.scatter(train.ENGINESIZE,train.CO2EMISSIONS,color='blue')
plt.plot(train_x,regr.coef_[0][0]*train_x + regr.intercept_[0],'-r')
plt.xlabel('Engine Size')
plt.ylabel('Emission')
plt.show()

# %% [markdown]
# CALCULATING ACCURACY OF THE MODEL

# %%
test_x=np.asanyarray(test[['ENGINESIZE']])
test_y=np.asanyarray(test[['CO2EMISSIONS']])
predictions=regr.predict(test_x)

MAE=f'Mean Absolute error[MAE] is {np.mean(np.absolute(predictions-test_y))}'
MSE=f'Mean Squared Error[MSE] is {np.mean((predictions-test_y)**2)}'
r2=f'R2-score is {r2_score(test_y,predictions)}'
print(f'{MAE}\n{MSE}\n{r2}')
# Out:
# Mean Absolute error[MAE] is 24.115040833386544
# Mean Squared Error[MSE] is 1021.1330721299404
# R2-score is 0.764353453584523

# %% [markdown]
# TRAINING/MODELLING DATA USING 'FUELCONSUMPTION_COMB' AGAINST 'CO2EMISSIONS'

# %%
regr=linear_model.LinearRegression()
train_x=np.asanyarray(train[['FUELCONSUMPTION_COMB']])
train_y=np.asanyarray(train[['CO2EMISSIONS']])
regr.fit(train_x,train_y)

print(f'Coefficent[Theta 1] :{regr.coef_}\nIntercept[Theta 0] :{regr.intercept_}')
# Out:
# Coefficent[Theta 1] :[[16.10353258]]
# Intercept[Theta 0] :[69.66484519]

# %% [markdown]
# Plotting fitted line

# %%
plt.scatter(train.FUELCONSUMPTION_COMB,train.CO2EMISSIONS,color='blue')
plt.plot(train_x,regr.coef_[0][0]*train_x+regr.intercept_[0],'-r')
plt.xlabel('FuelConsumption')
plt.ylabel('Emissions')
plt.show()

# %% [markdown]
# CALCULATING ACCURACY OF THE MODEL

# %%
test_x=np.asanyarray(test[['FUELCONSUMPTION_COMB']])
test_y=np.asanyarray(test[['CO2EMISSIONS']])
predictions=regr.predict(test_x)


MAE=f'Mean Absolute error[MAE] is {np.mean(np.absolute(predictions-test_y))}'
MSE=f'Mean Squared Error[MSE] is {np.mean((predictions-test_y)**2)}'
r2=f'R2-score is {r2_score(test_y,predictions)}'
print(f'{MAE}\n{MSE}\n{r2}')
# Out:
# Mean Absolute error[MAE] is 20.43972937815192
# Mean Squared Error[MSE] is 840.3683186151974
# R2-score is 0.806068476867966
